# %%
# Dependencies
import json
import requests
import pandas as pd
import csv
from config import api_key

# %%
# Save config information
url = "https://www.alphavantage.co/query?function=TIME_SERIES_DAILY"
# city = "London"

# Build query URL
query_url = url + "&symbol=ULTA" + "&outputsize=full"+ "&apikey=api_key" 
query_url
# Out:
# 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY&symbol=ULTA&outputsize=full&apikey=api_key'

# %%
response = requests.get(query_url)
ULTA_json = response.json()
ULTA_json
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#   '2. Symbol': 'ULTA',
#   '3. Last Refreshed': '2020-02-04',
#   '4. Output Size': 'Full size',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2020-02-04': {'1. open': '277.5200',
#    '2. high': '279.8800',
#    '3. low': '272.8600',
#    '4. close': '273.5200',
#    '5. volume': '957657'},
#   '2020-02-03': {'1. open': '273.0000',
#    '2. high': '280.0000',
#    '3. low': '272.1600',
#    '4. close': '274.9600',
#    '5. volume': '947958'},
#   '2020-01-31': {'1. open': '274.2700',
#    '2. high': '274.2700',
#    '3. low': '266.7375',
#    '4. close': '267.9100',
#    '5. volume': '730840'},
#   '2020-01-30': {'1. open': '270.5500',
#    '2. high': '275.0000',
#    '3. low': '270.1500',
#    '4. close': '274.4900',
#    '5. volume': '621514'},
#   '2020-01-29': {'1. open': '274.5000',
#    '2. high': '275.6900',
#    '3. low': '271.1100',
#    '4. close': '273.9800',
#    '5. volume': '476980'},
#   '2020-01-28': {'1. open': '275.0000',
#    '2. high': '277.2600',
#    '3. low': '271.7800',
#    '4. close': '273.8700',
#    '5. volume': '636127'},
#   '2020-01-27': {'1. open': '267.3600',
#    '2. high': '276.5100',
#    '3. low': '266.2100',
#    '4. close': '273.7000',
#    '5. volume': '837826'},
#   '2020-01-24': {'1. open': '272.2600',
#    '2. high': '275.2400',
#    '3. low': '270.8700',
#    '4. close': '272.9800',
#    '5. volume': '786360'},
#   '2020-01-23': {'1. open': '273.7300',
#    '2. high': '274.3900',
#    '3. low': '268.9300',
#    '4. close': '272.2000',
#    '5. volume': '904451'},
#   '2020-01-22': {'1. open': '273.3800',
#    '2. high': '276.1900',
#    '3. low': '272.5000',
#    '4. close': '273.9200',
#    '5. volume': '1068294'},
#   '2020-01-21': {'1. open': '272.8900',
#    '2. high': '276.8400',
#    '3. low': '269.7500',
#    '4. close': '272.0100',
#    '5. volume': '1089590'},
#   '2020-01-17': {'1. open': '278.0000',
#    '2. high': '278.1900',
#    '3. low': '271.1800',
#    '4. close': '272.8900',
#    '5. volume': '805475'},
#   '2020-01-16': {'1. open': '277.9900',
#    '2. high': '280.1600',
#    '3. low': '276.3500',
#    '4. close': '277.0000',
#    '5. volume': '715292'},
#   '2020-01-15': {'1. open': '282.6300',
#    '2. high': '284.0600',
#    '3. low': '275.8001',
#    '4. close': '276.2000',
#    '5. volume': '1469102'},
#   '2020-01-14': {'1. open': '276.3500',
#    '2. high': '283.1600',
#    '3. low': '276.1718',
#    '4. close': '282.6200',
#    '5. volume': '1480462'},
#   '2020-01-13': {'1. open': '269.2400',
#    '2. high': '279.4500',
#    '3. low': '269.0500',
#    '4. close': '275.7000',
#    '5. volume': '1868618'},
#   '2020-01-10': {'1. open': '264.1800',
#    '2. high': '267.3000',
#    '3. low': '262.4400',
#    '4. close': '267.2800',
#    '5. volume': '1454140'},
#   '2020-01-09': {'1. open': '259.6700',
#    '2. high': '266.3218',
#    '3. low': '259.3950',
#    '4. close': '263.5000',
#    '5. volume': '1580517'},
#   '2020-01-08': {'1. open': '252.4500',
#    '2. high': '259.1759',
#    '3. low': '252.4500',
#    '4. close': '258.0000',
#    '5. volume': '1123486'},
#   '2020-01-07': {'1. open': '250.4100',
#    '2. high': '254.8400',
#    '3. low': '250.0100',
#    '4. close': '253.0900',
#    '5. volume': '1161814'},
#   '2020-01-06': {'1. open': '248.7100',
#    '2. high': '251.0900',
#    '3. low': '246.7400',
#    '4. close': '250.9500',
#    '5. volume': '880606'},
#   '2020-01-03': {'1. open': '252.2800',
#    '2. high': '252.4800',
#    '3. low': '249.2200',
#    '4. close': '250.1700',
#    '5. volume': '921546'},
#   '2020-01-02': {'1. open': '254.3200',
#    '2. high': '254.8289',
#    '3. low': '250.6456',
#    '4. close': '254.5500',
#    '5. volume': '1160371'},
#   '2019-12-31': {'1. open': '251.2900',
#    '2. high': '253.7000',
#    '3. low': '250.3100',
#    '4. close': '253.1400',
#    '5. volume': '773817'},
#   '2019-12-30': {'1. open': '253.1800',
#    '2. high': '254.0500',
#    '3. low': '249.7098',
#    '4. close': '251.3500',
#    '5. volume': '652901'},
#   '2019-12-27': {'1. open': '252.6200',
#    '2. high': '255.6200',
#    '3. low': '251.7500',
#    '4. close': '253.1700',
#    '5. volume': '744629'},
#   '2019-12-26': {'1. open': '253.0000',
#    '2. high': '255.4900',
#    '3. low': '248.7818',
#    '4. close': '251.3300',
#    '5. volume': '776791'},
#   '2019-12-24': {'1. open': '253.2200',
#    '2. high': '257.6900',
#    '3. low': '252.2200',
#    '4. close': '252.4900',
#    '5. volume': '534412'},
#   '2019-12-23': {'1. open': '252.0500',
#    '2. high': '253.5499',
#    '3. low': '250.8400',
#    '4. close': '253.0200',
#    '5. volume': '996702'},
#   '2019-12-20': {'1. open': '251.1800',
#    '2. high': '251.1800',
#    '3. low': '247.5600',
#    '4. close': '250.5000',
#    '5. volume': '1984079'},
#   '2019-12-19': {'1. open': '251.4200',
#    '2. high': '251.8794',
#    '3. low': '247.0500',
#    '4. close': '250.6900',
#    '5. volume': '1126346'},
#   '2019-12-18': {'1. open': '256.2200',
#    '2. high': '256.4860',
#    '3. low': '249.0000',
#    '4. close': '250.0700',
#    '5. volume': '1320087'},
#   '2019-12-17': {'1. open': '249.0000',
#    '2. high': '256.0800',
#    '3. low': '248.8000',
#    '4. close': '255.9600',
#    '5. volume': '1043967'},
#   '2019-12-16': {'1. open': '254.5300',
#    '2. high': '255.8400',
#    '3. low': '248.3500',
#    '4. close': '249.1000',
#    '5. volume': '1025738'},
#   '2019-12-13': {'1. open': '259.4000',
#    '2. high': '260.2200',
#    '3. low': '253.4000',
#    '4. close': '253.5000',
#    '5. volume': '993261'},
#   '2019-12-12': {'1. open': '252.5100',
#    '2. high': '259.6200',
#    '3. low': '250.9100',
#    '4. close': '258.8700',
#    '5. volume': '1209674'},
#   '2019-12-11': {'1. open': '250.2700',
#    '2. high': '251.7900',
#    '3. low': '245.9200',
#    '4. close': '251.6400',
#    '5. volume': '1171937'},
#   '2019-12-10': {'1. open': '251.7000',
#    '2. high': '252.7300',
#    '3. low': '248.5800',
#    '4. close': '250.3700',
#    '5. volume': '1739950'},
#   '2019-12-09': {'1. open': '260.3900',
#    '2. high': '260.8400',
#    '3. low': '252.5200',
#    '4. close': '252.6400',
#    '5. volume': '2738436'},
#   '2019-12-06': {'1. open': '256.8600',
#    '2. high': '269.8900',
#    '3. low': '254.4000',
#    '4. close': '262.2000',
#    '5. volume': '6790548'},
#   '2019-12-05': {'1. open': '241.1000',
#    '2. high': '244.2764',
#    '3. low': '234.6900',
#    '4. close': '236.0200',
#    '5. volume': '3064414'},
#   '2019-12-04': {'1. open': '238.4900',
#    '2. high': '242.4500',
#    '3. low': '237.5100',
#    '4. close': '239.4250',
#    '5. volume': '1354847'},
#   '2019-12-03': {'1. open': '235.2400',
#    '2. high': '238.1100',
#    '3. low': '234.2600',
#    '4. close': '237.1000',
#    '5. volume': '1126341'},
#   '2019-12-02': {'1. open': '233.3700',
#    '2. high': '237.1850',
#    '3. low': '232.6170',
#    '4. close': '236.2700',
#    '5. volume': '1144320'},
#   '2019-11-29': {'1. open': '234.3600',
#    '2. high': '236.5100',
#    '3. low': '232.8210',
#    '4. close': '233.8600',
#    '5. volume': '661149'},
#   '2019-11-27': {'1. open': '237.4700',
#    '2. high': '242.4300',
#    '3. low': '233.4750',
#    '4. close': '233.9800',
#    '5. volume': '1405634'},
#   '2019-11-26': {'1. open': '231.1300',
#    '2. high': '236.8522',
#    '3. low': '231.1300',
#    '4. close': '235.9700',
#    '5. volume': '1555605'},
#   '2019-11-25': {'1. open': '227.8100',
#    '2. high': '231.5123',
#    '3. low': '222.0000',
#    '4. close': '231.2100',
#    '5. volume': '2191263'},
#   '2019-11-22': {'1. open': '229.0000',
#    '2. high': '231.9500',
#    '3. low': '227.1300',
#    '4. close': '228.8600',
#    '5. volume': '1853947'},
#   '2019-11-21': {'1. open': '234.3500',
#    '2. high': '237.6350',
#    '3. low': '226.7100',
#    '4. close': '228.4900',
#    '5. volume': '2393018'},
#   '2019-11-20': {'1. open': '236.8300',
#    '2. high': '236.9500',
#    '3. low': '231.9700',
#    '4. close': '234.2900',
#    '5. volume': '1764634'},
#   '2019-11-19': {'1. open': '243.7900',
#    '2. high': '243.8500',
#    '3. low': '238.2800',
#    '4. close': '239.6000',
#    '5. volume': '1111997'},
#   '2019-11-18': {'1. open': '245.4700',
#    '2. high': '245.9900',
#    '3. low': '242.7600',
#    '4. close': '244.3300',
#    '5. volume': '810438'},
#   '2019-11-15': {'1. open': '243.1400',
#    '2. high': '246.7300',
#    '3. low': '240.1300',
#    '4. close': '246.3000',
#    '5. volume': '872448'},
#   '2019-11-14': {'1. open': '244.9500',
#    '2. high': '245.6647',
#    '3. low': '241.3500',
#    '4. close': '242.8700',
#    '5. volume': '710244'},
#   '2019-11-13': {'1. open': '241.9900',
#    '2. high': '245.1400',
#    '3. low': '238.6429',
#    '4. close': '244.0400',
#    '5. volume': '582441'},
#   '2019-11-12': {'1. open': '241.1600',
#    '2. high': '246.1000',
#    '3. low': '239.7400',
#    '4. close': '243.9700',
#    '5. volume': '867457'},
#   '2019-11-11': {'1. open': '238.7800',
#    '2. high': '243.6800',
#    '3. low': '238.7800',
#    '4. close': '241.9600',
#    '5. volume': '611967'},
#   '2019-11-08': {'1. open': '242.2300',
#    '2. high': '243.2000',
#    '3. low': '238.3000',
#    '4. close': '239.2900',
#    '5. volume': '852814'},
#   '2019-11-07': {'1. open': '246.5900',
#    '2. high': '248.8800',
#    '3. low': '243.4500',
#    '4. close': '243.7700',
#    '5. volume': '763208'},
#   '2019-11-06': {'1. open': '246.1100',
#    '2. high': '246.7500',
#    '3. low': '241.3500',
#    '4. close': '243.9900',
#    '5. volume': '627044'},
#   '2019-11-05': {'1. open': '237.5100',
#    '2. high': '247.6400',
#    '3. low': '237.5100',
#    '4. close': '245.4200',
#    '5. volume': '1517161'},
#   '2019-11-04': {'1. open': '233.9500',
#    '2. high': '237.5799',
#    '3. low': '232.0900',
#    '4. close': '237.1900',
#    '5. volume': '1890520'},
#   '2019-11-01': {'1. open': '235.1600',
#    '2. high': '235.4699',
#    '3. low': '232.9000',
#    '4. close': '233.1100',
#    '5. volume': '1533565'},
#   '2019-10-31': {'1. open': '239.9600',
#    '2. high': '240.2500',
#    '3. low': '229.7900',
#    '4. close': '233.1500',
#    '5. volume': '2443196'},
#   '2019-10-30': {'1. open': '241.7600',
#    '2. high': '241.7700',
#    '3. low': '238.1800',
#    '4. close': '240.2500',
#    '5. volume': '593305'},
#   '2019-10-29': {'1. open': '242.0800',
#    '2. high': '243.9800',
#    '3. low': '237.3700',
#    '4. close': '242.1100',
#    '5. volume': '908754'},
#   '2019-10-28': {'1. open': '240.0000',
#    '2. high': '246.6000',
#    '3. low': '240.0000',
#    '4. close': '241.7400',
#    '5. volume': '1159825'},
#   '2019-10-25': {'1. open': '238.3800',
#    '2. high': '242.4750',
#    '3. low': '237.7300',
#    '4. close': '240.9000',
#    '5. volume': '659343'},
#   '2019-10-24': {'1. open': '237.7700',
#    '2. high': '240.8500',
#    '3. low': '236.2700',
#    '4. close': '238.9300',
#    '5. volume': '889662'},
#   '2019-10-23': {'1. open': '237.4100',
#    '2. high': '238.2400',
#    '3. low': '231.0800',
#    '4. close': '237.8700',
#    '5. volume': '956899'},
#   '2019-10-22': {'1. open': '236.2600',
#    '2. high': '240.3800',
#    '3. low': '236.2600',
#    '4. close': '236.9100',
#    '5. volume': '1001014'},
#   '2019-10-21': {'1. open': '240.5700',
#    '2. high': '241.0400',
#    '3. low': '235.2400',
#    '4. close': '235.3000',
#    '5. volume': '1673405'},
#   '2019-10-18': {'1. open': '246.8000',
#    '2. high': '247.2385',
#    '3. low': '239.8000',
#    '4. close': '239.9200',
#    '5. volume': '1307451'},
#   '2019-10-17': {'1. open': '244.9700',
#    '2. high': '251.6700',
#    '3. low': '244.9700',
#    '4. close': '248.1000',
#    '5. volume': '1153722'},
#   '2019-10-16': {'1. open': '245.7100',
#    '2. high': '247.7299',
#    '3. low': '243.5100',
#    '4. close': '244.9800',
#    '5. volume': '723055'},
#   '2019-10-15': {'1. open': '247.0100',
#    '2. high': '249.1900',
#    '3. low': '244.2500',
#    '4. close': '245.4000',
#    '5. volume': '724072'},
#   '2019-10-14': {'1. open': '247.0700',
#    '2. high': '249.3900',
#    '3. low': '245.8000',
#    '4. close': '246.5700',
#    '5. volume': '768291'},
#   '2019-10-11': {'1. open': '245.4100',
#    '2. high': '249.5500',
#    '3. low': '244.1150',
#    '4. close': '248.4600',
#    '5. volume': '1246627'},
#   '2019-10-10': {'1. open': '237.6500',
#    '2. high': '242.3000',
#    '3. low': '237.0228',
#    '4. close': '241.7500',
#    '5. volume': '1144269'},
#   '2019-10-09': {'1. open': '238.1400',
#    '2. high': '240.6700',
#    '3. low': '235.6701',
#    '4. close': '238.0400',
#    '5. volume': '1494676'},
#   '2019-10-08': {'1. open': '240.0600',
#    '2. high': '240.9900',
#    '3. low': '235.2000',
#    '4. close': '237.0300',
#    '5. volume': '3531666'},
#   '2019-10-07': {'1. open': '250.2500',
#    '2. high': '250.9800',
#    '3. low': '242.3200',
#    '4. close': '242.7500',
#    '5. volume': '2308657'},
#   '2019-10-04': {'1. open': '257.7100',
#    '2. high': '258.0937',
#    '3. low': '250.2600',
#    '4. close': '250.6000',
#    '5. volume': '1724765'},
#   '2019-10-03': {'1. open': '263.3700',
#    '2. high': '265.2100',
#    '3. low': '250.6500',
#    '4. close': '257.4300',
#    '5. volume': '2261053'},
#   '2019-10-02': {'1. open': '263.3100',
#    '2. high': '264.0000',
#    '3. low': '256.8900',
#    '4. close': '262.7900',
#    '5. volume': '2495100'},
#   '2019-10-01': {'1. open': '253.4500',
#    '2. high': '267.2500',
#    '3. low': '253.0100',
#    '4. close': '265.9900',
#    '5. volume': '4329279'},
#   '2019-09-30': {'1. open': '245.5800',
#    '2. high': '251.7600',
#    '3. low': '245.0000',
#    '4. close': '250.6500',
#    '5. volume': '2335643'},
#   '2019-09-27': {'1. open': '238.1400',
#    '2. high': '246.4600',
#    '3. low': '237.4000',
#    '4. close': '244.4000',
#    '5. volume': '2107582'},
#   '2019-09-26': {'1. open': '236.4000',
#    '2. high': '238.5300',
#    '3. low': '234.7500',
#    '4. close': '236.3100',
#    '5. volume': '1190741'},
#   '2019-09-25': {'1. open': '238.7500',
#    '2. high': '239.4250',
#    '3. low': '233.2786',
#    '4. close': '235.5400',
#    '5. volume': '1421394'},
#   '2019-09-24': {'1. open': '237.8900',
#    '2. high': '241.3000',
#    '3. low': '235.2949',
#    '4. close': '239.4800',
#    '5. volume': '2325962'},
#   '2019-09-23': {'1. open': '229.5500',
#    '2. high': '239.9200',
#    '3. low': '229.2700',
#    '4. close': '237.3100',
#    '5. volume': '2382930'},
#   '2019-09-20': {'1. open': '229.7900',
#    '2. high': '232.2600',
#    '3. low': '227.6500',
#    '4. close': '228.7500',
#    '5. volume': '2013240'},
#   '2019-09-19': {'1. open': '229.6000',
#    '2. high': '232.7000',
#    '3. low': '228.6100',
#    '4. close': '230.0700',
#    '5. volume': '1105848'},
#   '2019-09-18': {'1. open': '233.7400',
#    '2. high': '233.7400',
#    '3. low': '227.3800',
#    '4. close': '229.3400',
#    '5. volume': '1685239'},
#   '2019-09-17': {'1. open': '225.6900',
#    '2. high': '235.0900',
#    '3. low': '225.1500',
#    '4. close': '233.8500',
#    '5. volume': '2217206'},
#   '2019-09-16': {'1. open': '226.2600',
#    '2. high': '230.1200',
#    '3. low': '224.6557',
#    '4. close': '225.4500',
#    '5. volume': '1361659'},
#   '2019-09-13': {'1. open': '227.6000',
#    '2. high': '227.9500',
#    '3. low': '225.5300',
#    '4. close': '226.8600',
#    '5. volume': '1127024'},
#   '2019-09-12': {'1. open': '229.0600',
#    '2. high': '229.3599',
#    '3. low': '225.1200',
#    '4. close': '226.1600',
#    '5. volume': '1872456'},
#   '2019-09-11': {'1. open': '231.6800',
#    '2. high': '233.8800',
#    '3. low': '227.2600',
#    '4. close': '228.1500',
#    '5. volume': '1496657'},
#   '2019-09-10': {'1. open': '225.5000',
#    '2. high': '233.1700',
#    '3. low': '225.2800',
#    '4. close': '231.4200',
#    '5. volume': '2241474'},
#   '2019-09-09': {'1. open': '233.7400',
#    '2. high': '234.1700',
#    '3. low': '226.0300',
#    '4. close': '226.1600',
#    '5. volume': '2181315'},
#   '2019-09-06': {'1. open': '237.8400',
#    '2. high': '239.2400',
#    '3. low': '233.0300',
#    '4. close': '233.1000',
#    '5. volume': '2026045'},
#   '2019-09-05': {'1. open': '229.0300',
#    '2. high': '237.8500',
#    '3. low': '227.7100',
#    '4. close': '236.7100',
#    '5. volume': '3264312'},
#   '2019-09-04': {'1. open': '238.0000',
#    '2. high': '239.8600',
#    '3. low': '228.2000',
#    '4. close': '228.7600',
#    '5. volume': '4028313'},
#   '2019-09-03': {'1. open': '234.0500',
#    '2. high': '244.2100',
#    '3. low': '231.0200',
#    '4. close': '237.4100',
#    '5. volume': '5435457'},
#   '2019-08-30': {'1. open': '252.8100',
#    '2. high': '254.4990',
#    '3. low': '235.7600',
#    '4. close': '237.7300',
#    '5. volume': '16116168'},
#   '2019-08-29': {'1. open': '337.5000',
#    '2. high': '342.0000',
#    '3. low': '333.0900',
#    '4. close': '337.4500',
#    '5. volume': '3171999'},
#   '2019-08-28': {'1. open': '323.7700',
#    '2. high': '331.4500',
#    '3. low': '321.1600',
#    '4. close': '330.3800',
#    '5. volume': '748079'},
#   '2019-08-27': {'1. open': '333.1600',
#    '2. high': '334.7999',
#    '3. low': '323.6000',
#    '4. close': '323.7700',
#    '5. volume': '1001709'},
#   '2019-08-26': {'1. open': '327.0000',
#    '2. high': '331.9900',
#    '3. low': '324.5400',
#    '4. close': '330.2200',
#    '5. volume': '1008562'},
#   '2019-08-23': {'1. open': '330.6400',
#    '2. high': '332.3700',
#    '3. low': '321.2425',
#    '4. close': '322.1000',
#    '5. volume': '1100266'},
#   '2019-08-22': {'1. open': '328.5400',
#    '2. high': '338.5000',
#    '3. low': '328.5400',
#    '4. close': '334.8700',
#    '5. volume': '755990'},
#   '2019-08-21': {'1. open': '327.2400',
#    '2. high': '331.4860',
#    '3. low': '326.8100',
#    '4. close': '328.1200',
#    '5. volume': '521112'},
#   '2019-08-20': {'1. open': '325.1700',
#    '2. high': '328.2800',
#    '3. low': '320.5100',
#    '4. close': '323.0800',
#    '5. volume': '475818'},
#   '2019-08-19': {'1. open': '327.4300',
#    '2. high': '328.7650',
#    '3. low': '322.4500',
#    '4. close': '325.2500',
#    '5. volume': '812589'},
#   '2019-08-16': {'1. open': '323.5200',
#    '2. high': '327.8900',
#    '3. low': '319.2600',
#    '4. close': '322.0300',
#    '5. volume': '573548'},
#   '2019-08-15': {'1. open': '320.7400',
#    '2. high': '324.8650',
#    '3. low': '315.4900',
#    '4. close': '320.4400',
#    '5. volume': '990467'},
#   '2019-08-14': {'1. open': '330.0600',
#    '2. high': '332.2000',
#    '3. low': '320.1650',
#    '4. close': '321.0000',
#    '5. volume': '1249274'},
#   '2019-08-13': {'1. open': '334.3100',
#    '2. high': '348.3150',
#    '3. low': '333.3344',
#    '4. close': '341.2000',
#    '5. volume': '576810'},
#   '2019-08-12': {'1. open': '345.9100',
#    '2. high': '345.9100',
#    '3. low': '332.6800',
#    '4. close': '336.5100',
#    '5. volume': '759225'},
#   '2019-08-09': {'1. open': '351.4900',
#    '2. high': '353.3994',
#    '3. low': '345.0000',
#    '4. close': '346.7000',
#    '5. volume': '522708'},
#   '2019-08-08': {'1. open': '345.1800',
#    '2. high': '355.3600',
#    '3. low': '344.7600',
#    '4. close': '353.0400',
#    '5. volume': '588157'},
#   '2019-08-07': {'1. open': '337.2200',
#    '2. high': '344.3600',
#    '3. low': '336.7000',
#    '4. close': '343.6800',
#    '5. volume': '756093'},
#   '2019-08-06': {'1. open': '330.3700',
#    '2. high': '340.9500',
#    '3. low': '329.0000',
#    '4. close': '340.2800',
#    '5. volume': '688204'},
#   '2019-08-05': {'1. open': '331.9800',
#    '2. high': '331.9800',
#    '3. low': '326.3400',
#    '4. close': '330.1400',
#    '5. volume': '728400'},
#   '2019-08-02': {'1. open': '346.2400',
#    '2. high': '348.5700',
#    '3. low': '334.1600',
#    '4. close': '337.0200',
#    '5. volume': '811059'},
#   '2019-08-01': {'1. open': '348.7300',
#    '2. high': '352.0800',
#    '3. low': '341.8950',
#    '4. close': '345.5100',
#    '5. volume': '683861'},
#   '2019-07-31': {'1. open': '347.6200',
#    '2. high': '354.0000',
#    '3. low': '344.3650',
#    '4. close': '349.2500',
#    '5. volume': '521277'},
#   '2019-07-30': {'1. open': '345.0300',
#    '2. high': '350.4500',
#    '3. low': '342.1516',
#    '4. close': '348.6300',
#    '5. volume': '579725'},
#   '2019-07-29': {'1. open': '352.6700',
#    '2. high': '353.1950',
#    '3. low': '341.4000',
#    '4. close': '346.1300',
#    '5. volume': '815667'},
#   '2019-07-26': {'1. open': '355.7200',
#    '2. high': '356.0450',
#    '3. low': '349.5600',
#    '4. close': '353.8800',
#    '5. volume': '497649'},
#   '2019-07-25': {'1. open': '353.7300',
#    '2. high': '359.7400',
#    '3. low': '352.0000',
#    '4. close': '354.6200',
#    '5. volume': '486877'},
#   '2019-07-24': {'1. open': '351.9900',
#    '2. high': '353.1700',
#    '3. low': '348.7500',
#    '4. close': '352.9400',
#    '5. volume': '532145'},
#   '2019-07-23': {'1. open': '354.0000',
#    '2. high': '354.1100',
#    '3. low': '349.9800',
#    '4. close': '351.9900',
#    '5. volume': '648404'},
#   '2019-07-22': {'1. open': '357.7900',
#    '2. high': '359.8000',
#    '3. low': '351.0900',
#    '4. close': '352.9500',
#    '5. volume': '550264'},
#   '2019-07-19': {'1. open': '365.1900',
#    '2. high': '367.0100',
#    '3. low': '356.4500',
#    '4. close': '357.0000',
#    '5. volume': '574627'},
#   '2019-07-18': {'1. open': '363.5500',
#    '2. high': '368.7200',
#    '3. low': '363.5500',
#    '4. close': '366.2100',
#    '5. volume': '518659'},
#   '2019-07-17': {'1. open': '361.5200',
#    '2. high': '368.8300',
#    '3. low': '361.5200',
#    '4. close': '366.3900',
#    '5. volume': '713716'},
#   '2019-07-16': {'1. open': '356.5700',
#    '2. high': '361.8500',
#    '3. low': '355.6100',
#    '4. close': '360.5400',
#    '5. volume': '1409531'},
#   '2019-07-15': {'1. open': '356.9700',
#    '2. high': '361.2700',
#    '3. low': '354.3001',
#    '4. close': '355.6800',
#    '5. volume': '741664'},
#   '2019-07-12': {'1. open': '348.0000',
#    '2. high': '357.2750',
#    '3. low': '347.2700',
#    '4. close': '356.3900',
#    '5. volume': '651431'},
#   '2019-07-11': {'1. open': '348.0000',
#    '2. high': '349.9500',
#    '3. low': '346.1550',
#    '4. close': '346.9800',
#    '5. volume': '537158'},
#   '2019-07-10': {'1. open': '349.3800',
#    '2. high': '349.9100',
#    '3. low': '342.7800',
#    '4. close': '347.2000',
#    '5. volume': '595659'},
#   '2019-07-09': {'1. open': '351.2000',
#    '2. high': '353.1900',
#    '3. low': '347.0000',
#    '4. close': '348.4800',
#    '5. volume': '729058'},
#   '2019-07-08': {'1. open': '343.6100',
#    '2. high': '353.0800',
#    '3. low': '343.6100',
#    '4. close': '352.6900',
#    '5. volume': '623014'},
#   '2019-07-05': {'1. open': '343.3300',
#    '2. high': '348.4900',
#    '3. low': '343.3300',
#    '4. close': '344.9500',
#    '5. volume': '481437'},
#   '2019-07-03': {'1. open': '343.6500',
#    '2. high': '346.0000',
#    '3. low': '341.2100',
#    '4. close': '345.4300',
#    '5. volume': '330025'},
#   '2019-07-02': {'1. open': '340.7600',
#    '2. high': '345.7800',
#    '3. low': '338.2500',
#    '4. close': '341.3300',
#    '5. volume': '590555'},
#   '2019-07-01': {'1. open': '350.5500',
#    '2. high': '353.7600',
#    '3. low': '339.8800',
#    '4. close': '340.3800',
#    '5. volume': '794018'},
#   '2019-06-28': {'1. open': '345.9400',
#    '2. high': '347.3800',
#    '3. low': '343.8900',
#    '4. close': '346.8900',
#    '5. volume': '784345'},
#   '2019-06-27': {'1. open': '346.5000',
#    '2. high': '347.4250',
#    '3. low': '339.5305',
#    '4. close': '344.2200',
#    '5. volume': '619539'},
#   '2019-06-26': {'1. open': '350.5800',
#    '2. high': '352.6500',
#    '3. low': '344.2700',
#    '4. close': '344.8200',
#    '5. volume': '561798'},
#   '2019-06-25': {'1. open': '345.0000',
#    '2. high': '348.9200',
#    '3. low': '340.8745',
#    '4. close': '348.6900',
#    '5. volume': '640656'},
#   '2019-06-24': {'1. open': '357.7300',
#    '2. high': '358.6900',
#    '3. low': '340.2600',
#    '4. close': '346.5400',
#    '5. volume': '1684659'},
#   '2019-06-21': {'1. open': '359.2800',
#    '2. high': '360.4700',
#    '3. low': '355.2800',
#    '4. close': '355.8100',
#    '5. volume': '730417'},
#   '2019-06-20': {'1. open': '360.4200',
#    '2. high': '365.5350',
#    '3. low': '355.1650',
#    '4. close': '358.3400',
#    '5. volume': '743500'},
#   '2019-06-19': {'1. open': '346.7700',
#    '2. high': '358.4300',
#    '3. low': '343.6280',
#    '4. close': '357.8400',
#    '5. volume': '564870'},
#   '2019-06-18': {'1. open': '352.5800',
#    '2. high': '354.0900',
#    '3. low': '345.9000',
#    '4. close': '347.2100',
#    '5. volume': '617834'},
#   '2019-06-17': {'1. open': '355.6100',
#    '2. high': '357.5400',
#    '3. low': '349.5600',
#    '4. close': '350.1900',
#    '5. volume': '605421'},
#   '2019-06-14': {'1. open': '349.3400',
#    '2. high': '355.6100',
#    '3. low': '349.0271',
#    '4. close': '354.6200',
#    '5. volume': '905076'},
#   '2019-06-13': {'1. open': '344.6200',
#    '2. high': '350.2000',
#    '3. low': '343.6236',
#    '4. close': '349.8100',
#    '5. volume': '732345'},
#   '2019-06-12': {'1. open': '341.8800',
#    '2. high': '343.8800',
#    '3. low': '339.1400',
#    '4. close': '342.8200',
#    '5. volume': '480842'},
#   '2019-06-11': {'1. open': '341.2200',
#    '2. high': '341.8900',
#    '3. low': '334.5600',
#    '4. close': '340.0100',
#    '5. volume': '431001'},
#   '2019-06-10': {'1. open': '339.1100',
#    '2. high': '344.4900',
#    '3. low': '335.6300',
#    '4. close': '337.0500',
#    '5. volume': '561587'},
#   '2019-06-07': {'1. open': '340.6900',
#    '2. high': '343.9600',
#    '3. low': '337.6800',
#    '4. close': '338.1600',
#    '5. volume': '567317'},
#   '2019-06-06': {'1. open': '339.8500',
#    '2. high': '341.9600',
#    '3. low': '336.3800',
#    '4. close': '340.3300',
#    '5. volume': '590749'},
#   '2019-06-05': {'1. open': '338.0100',
#    '2. high': '338.6400',
#    '3. low': '331.2600',
#    '4. close': '337.4800',
#    '5. volume': '577235'},
#   '2019-06-04': {'1. open': '332.3000',
#    '2. high': '340.5500',
#    '3. low': '331.6000',
#    '4. close': '335.5300',
#    '5. volume': '773624'},
#   '2019-06-03': {'1. open': '333.8900',
#    '2. high': '337.3600',
#    '3. low': '327.8500',
#    '4. close': '330.6000',
#    '5. volume': '1023700'},
#   '2019-05-31': {'1. open': '315.3300',
#    '2. high': '335.1263',
#    '3. low': '304.0400',
#    '4. close': '333.3800',
#    '5. volume': '3198001'},
#   '2019-05-30': {'1. open': '327.6400',
#    '2. high': '334.0253',
#    '3. low': '321.1800',
#    '4. close': '328.4600',
#    '5. volume': '1317968'},
#   '2019-05-29': {'1. open': '332.3700',
#    '2. high': '334.5900',
#    '3. low': '321.8200',
#    '4. close': '322.0700',
#    '5. volume': '1033748'},
#   '2019-05-28': {'1. open': '336.2200',
#    '2. high': '338.5000',
#    '3. low': '333.0100',
#    '4. close': '334.8500',
#    '5. volume': '1026708'},
#   '2019-05-24': {'1. open': '338.8100',
#    '2. high': '340.8400',
#    '3. low': '330.4300',
#    '4. close': '335.0900',
#    '5. volume': '615107'},
#   '2019-05-23': {'1. open': '347.0300',
#    '2. high': '347.1398',
#    '3. low': '336.0700',
#    '4. close': '337.8300',
#    '5. volume': '1026755'},
#   '2019-05-22': {'1. open': '351.8000',
#    '2. high': '354.6200',
#    '3. low': '348.8900',
#    '4. close': '349.0900',
#    '5. volume': '466345'},
#   '2019-05-21': {'1. open': '348.6100',
#    '2. high': '354.5400',
#    '3. low': '347.9000',
#    '4. close': '353.1600',
#    '5. volume': '545642'},
#   '2019-05-20': {'1. open': '340.5000',
#    '2. high': '348.3100',
#    '3. low': '339.0328',
#    '4. close': '347.8900',
#    '5. volume': '829220'},
#   '2019-05-17': {'1. open': '342.5900',
#    '2. high': '349.5600',
#    '3. low': '342.1000',
#    '4. close': '342.4500',
#    '5. volume': '573389'},
#   '2019-05-16': {'1. open': '341.3100',
#    '2. high': '348.4600',
#    '3. low': '341.3100',
#    '4. close': '343.2400',
#    '5. volume': '512094'},
#   '2019-05-15': {'1. open': '335.0600',
#    '2. high': '340.9500',
#    '3. low': '333.4700',
#    '4. close': '340.7000',
#    '5. volume': '677928'},
#   '2019-05-14': {'1. open': '332.5600',
#    '2. high': '336.8000',
#    '3. low': '325.6186',
#    '4. close': '335.3200',
#    '5. volume': '949187'},
#   '2019-05-13': {'1. open': '337.2100',
#    '2. high': '338.9800',
#    '3. low': '328.3400',
#    '4. close': '330.2300',
#    '5. volume': '813465'},
#   '2019-05-10': {'1. open': '347.0100',
#    '2. high': '347.0100',
#    '3. low': '337.0100',
#    '4. close': '343.2400',
#    '5. volume': '685578'},
#   '2019-05-09': {'1. open': '344.5200',
#    '2. high': '349.1300',
#    '3. low': '343.2800',
#    '4. close': '348.0500',
#    '5. volume': '460598'},
#   '2019-05-08': {'1. open': '341.8200',
#    '2. high': '350.5500',
#    '3. low': '340.0300',
#    '4. close': '348.1500',
#    '5. volume': '577399'},
#   '2019-05-07': {'1. open': '344.2900',
#    '2. high': '347.3100',
#    '3. low': '338.8946',
#    '4. close': '342.3600',
#    '5. volume': '698072'},
#   '2019-05-06': {'1. open': '336.5300',
#    '2. high': '347.6100',
#    '3. low': '335.7800',
#    '4. close': '346.6800',
#    '5. volume': '712071'},
#   '2019-05-03': {'1. open': '344.2700',
#    '2. high': '346.1200',
#    '3. low': '339.9800',
#    '4. close': '341.9600',
#    '5. volume': '728586'},
#   '2019-05-02': {'1. open': '335.0100',
#    '2. high': '344.1100',
#    '3. low': '335.0100',
#    '4. close': '343.6800',
#    '5. volume': '875374'},
#   '2019-05-01': {'1. open': '347.8100',
#    '2. high': '348.3300',
#    '3. low': '334.6500',
#    '4. close': '334.9400',
#    '5. volume': '1151636'},
#   '2019-04-30': {'1. open': '351.1200',
#    '2. high': '352.1600',
#    '3. low': '346.9900',
#    '4. close': '348.9800',
#    '5. volume': '736645'},
#   '2019-04-29': {'1. open': '356.9700',
#    '2. high': '357.8950',
#    '3. low': '350.6500',
#    '4. close': '350.9000',
#    '5. volume': '578949'},
#   '2019-04-26': {'1. open': '356.8600',
#    '2. high': '358.4350',
#    '3. low': '350.0100',
#    '4. close': '357.9400',
#    '5. volume': '572031'},
#   '2019-04-25': {'1. open': '355.3200',
#    '2. high': '355.3424',
#    '3. low': '348.5400',
#    '4. close': '353.7000',
#    '5. volume': '397588'},
#   '2019-04-24': {'1. open': '351.3300',
#    '2. high': '357.9100',
#    '3. low': '351.3300',
#    '4. close': '355.8400',
#    '5. volume': '444359'},
#   '2019-04-23': {'1. open': '347.7200',
#    '2. high': '355.8550',
#    '3. low': '347.4900',
#    '4. close': '351.6300',
#    '5. volume': '556517'},
#   '2019-04-22': {'1. open': '350.3300',
#    '2. high': '351.4700',
#    '3. low': '344.2600',
#    '4. close': '347.4100',
#    '5. volume': '525820'},
#   '2019-04-18': {'1. open': '356.6300',
#    '2. high': '359.0950',
#    '3. low': '350.2500',
#    '4. close': '350.8800',
#    '5. volume': '568164'},
#   '2019-04-17': {'1. open': '355.0800',
#    '2. high': '359.6900',
#    '3. low': '353.9300',
#    '4. close': '354.3300',
#    '5. volume': '525394'},
#   '2019-04-16': {'1. open': '354.7800',
#    '2. high': '356.8022',
#    '3. low': '349.4500',
#    '4. close': '355.0800',
#    '5. volume': '682236'},
#   '2019-04-15': {'1. open': '346.7600',
#    '2. high': '354.6700',
#    '3. low': '345.9900',
#    '4. close': '353.9400',
#    '5. volume': '678851'},
#   '2019-04-12': {'1. open': '350.6500',
#    '2. high': '351.8800',
#    '3. low': '344.2700',
#    '4. close': '344.8300',
#    '5. volume': '559597'},
#   '2019-04-11': {'1. open': '350.8800',
#    '2. high': '351.8700',
#    '3. low': '348.0025',
#    '4. close': '350.2200',
#    '5. volume': '708751'},
#   '2019-04-10': {'1. open': '349.7600',
#    '2. high': '350.8500',
#    '3. low': '345.3825',
#    '4. close': '350.2800',
#    '5. volume': '532422'},
#   '2019-04-09': {'1. open': '352.3600',
#    '2. high': '355.2807',
#    '3. low': '347.3000',
#    '4. close': '348.2000',
#    '5. volume': '551709'},
#   '2019-04-08': {'1. open': '353.5600',
#    '2. high': '355.7250',
#    '3. low': '351.2900',
#    '4. close': '354.4700',
#    '5. volume': '439663'},
#   '2019-04-05': {'1. open': '351.7300',
#    '2. high': '354.1800',
#    '3. low': '348.7400',
#    '4. close': '353.6300',
#    '5. volume': '590451'},
#   '2019-04-04': {'1. open': '350.5300',
#    '2. high': '352.5005',
#    '3. low': '347.7500',
#    '4. close': '350.1400',
#    '5. volume': '397210'},
#   '2019-04-03': {'1. open': '349.4700',
#    '2. high': '354.4400',
#    '3. low': '347.6300',
#    '4. close': '350.5300',
#    '5. volume': '507664'},
#   '2019-04-02': {'1. open': '353.3700',
#    '2. high': '354.0900',
#    '3. low': '346.5900',
#    '4. close': '347.3000',
#    '5. volume': '514410'},
#   '2019-04-01': {'1. open': '351.5000',
#    '2. high': '353.7750',
#    '3. low': '350.7400',
#    '4. close': '352.5500',
#    '5. volume': '582321'},
#   '2019-03-29': {'1. open': '347.6000',
#    '2. high': '350.0000',
#    '3. low': '344.9500',
#    '4. close': '348.7300',
#    '5. volume': '526476'},
#   '2019-03-28': {'1. open': '347.8900',
#    '2. high': '351.4340',
#    '3. low': '343.3041',
#    '4. close': '345.2300',
#    '5. volume': '667504'},
#   '2019-03-27': {'1. open': '343.7000',
#    '2. high': '348.4000',
#    '3. low': '343.3400',
#    '4. close': '346.0500',
#    '5. volume': '724648'},
#   '2019-03-26': {'1. open': '339.6200',
#    '2. high': '345.6300',
#    '3. low': '337.4500',
#    '4. close': '342.9000',
#    '5. volume': '847941'},
#   '2019-03-25': {'1. open': '330.8800',
#    '2. high': '338.2500',
#    '3. low': '330.8800',
#    '4. close': '336.6700',
#    '5. volume': '811861'},
#   '2019-03-22': {'1. open': '334.1800',
#    '2. high': '336.0700',
#    '3. low': '328.6343',
#    '4. close': '330.5200',
#    '5. volume': '695030'},
#   '2019-03-21': {'1. open': '329.2200',
#    '2. high': '336.5500',
#    '3. low': '328.8290',
#    '4. close': '335.1300',
#    '5. volume': '759099'},
#   '2019-03-20': {'1. open': '335.0000',
#    '2. high': '337.5000',
#    '3. low': '330.5100',
#    '4. close': '330.7900',
#    '5. volume': '934110'},
#   '2019-03-19': {'1. open': '342.9700',
#    '2. high': '343.9190',
#    '3. low': '331.3200',
#    '4. close': '334.4500',
#    '5. volume': '1461914'},
#   '2019-03-18': {'1. open': '338.6000',
#    '2. high': '344.5300',
#    '3. low': '336.8700',
#    '4. close': '342.2200',
#    '5. volume': '949808'},
#   '2019-03-15': {'1. open': '327.9700',
#    '2. high': '345.2400',
#    '3. low': '327.0000',
#    '4. close': '338.4100',
#    '5. volume': '3882889'},
#   '2019-03-14': {'1. open': '315.7300',
#    '2. high': '315.7300',
#    '3. low': '311.6100',
#    '4. close': '312.5100',
#    '5. volume': '1271170'},
#   '2019-03-13': {'1. open': '312.0500',
#    '2. high': '316.9800',
#    '3. low': '311.0600',
#    '4. close': '315.4400',
#    '5. volume': '796764'},
#   '2019-03-12': {'1. open': '310.6900',
#    '2. high': '312.0000',
#    '3. low': '304.3200',
#    '4. close': '311.4100',
#    '5. volume': '779268'},
#   '2019-03-11': {'1. open': '308.0000',
#    '2. high': '310.3400',
#    '3. low': '306.5650',
#    '4. close': '309.7500',
#    '5. volume': '905969'},
#   '2019-03-08': {'1. open': '302.8700',
#    '2. high': '306.9900',
#    '3. low': '294.0000',
#    '4. close': '306.3900',
#    '5. volume': '863981'},
#   '2019-03-07': {'1. open': '312.0100',
#    '2. high': '312.2000',
#    '3. low': '304.4800',
#    '4. close': '305.4500',
#    '5. volume': '877898'},
#   '2019-03-06': {'1. open': '312.1100',
#    '2. high': '313.2100',
#    '3. low': '308.9800',
#    '4. close': '312.5100',
#    '5. volume': '711465'},
#   '2019-03-05': {'1. open': '312.9800',
#    '2. high': '314.3000',
#    '3. low': '310.3000',
#    '4. close': '312.2400',
#    '5. volume': '963213'},
#   '2019-03-04': {'1. open': '316.9700',
#    '2. high': '317.7800',
#    '3. low': '308.0300',
#    '4. close': '311.5000',
#    '5. volume': '832668'},
#   '2019-03-01': {'1. open': '315.6100',
#    '2. high': '318.7790',
#    '3. low': '313.8200',
#    '4. close': '315.3000',
#    '5. volume': '553988'},
#   '2019-02-28': {'1. open': '306.0200',
#    '2. high': '315.1600',
#    '3. low': '304.3000',
#    '4. close': '312.4900',
#    '5. volume': '756350'},
#   '2019-02-27': {'1. open': '307.4800',
#    '2. high': '309.4700',
#    '3. low': '305.1200',
#    '4. close': '307.1100',
#    '5. volume': '642921'},
#   '2019-02-26': {'1. open': '308.6500',
#    '2. high': '311.0200',
#    '3. low': '308.1800',
#    '4. close': '310.0000',
#    '5. volume': '508317'},
#   '2019-02-25': {'1. open': '311.5400',
#    '2. high': '313.6299',
#    '3. low': '308.0300',
#    '4. close': '309.0500',
#    '5. volume': '546264'},
#   '2019-02-22': {'1. open': '309.6300',
#    '2. high': '310.9300',
#    '3. low': '308.0000',
#    '4. close': '310.7200',
#    '5. volume': '580745'},
#   '2019-02-21': {'1. open': '306.2800',
#    '2. high': '309.7000',
#    '3. low': '304.1150',
#    '4. close': '308.0200',
#    '5. volume': '671530'},
#   '2019-02-20': {'1. open': '304.6300',
#    '2. high': '307.5000',
#    '3. low': '303.0100',
#    '4. close': '306.3100',
#    '5. volume': '526971'},
#   '2019-02-19': {'1. open': '304.1000',
#    '2. high': '305.8200',
#    '3. low': '299.7600',
#    '4. close': '304.6500',
#    '5. volume': '1038415'},
#   '2019-02-15': {'1. open': '307.4200',
#    '2. high': '308.5250',
#    '3. low': '305.4400',
#    '4. close': '306.3600',
#    '5. volume': '565579'},
#   '2019-02-14': {'1. open': '302.6800',
#    '2. high': '307.5900',
#    '3. low': '300.9200',
#    '4. close': '305.0000',
#    '5. volume': '1257932'},
#   '2019-02-13': {'1. open': '304.1600',
#    '2. high': '304.8300',
#    '3. low': '299.7200',
#    '4. close': '303.9500',
#    '5. volume': '622060'},
#   '2019-02-12': {'1. open': '301.2300',
#    '2. high': '305.0000',
#    '3. low': '300.7300',
#    '4. close': '302.5000',
#    '5. volume': '535294'},
#   '2019-02-11': {'1. open': '296.2500',
#    '2. high': '302.3300',
#    '3. low': '296.2500',
#    '4. close': '298.1000',
#    '5. volume': '668155'},
#   '2019-02-08': {'1. open': '291.5800',
#    '2. high': '296.4800',
#    '3. low': '289.2500',
#    '4. close': '296.0600',
#    '5. volume': '782013'},
#   '2019-02-07': {'1. open': '291.1800',
#    '2. high': '294.5700',
#    '3. low': '288.0900',
#    '4. close': '293.6400',
#    '5. volume': '463682'},
#   '2019-02-06': {'1. open': '293.5700',
#    '2. high': '295.9500',
#    '3. low': '288.0500',
#    '4. close': '293.4500',
#    '5. volume': '506785'},
#   '2019-02-05': {'1. open': '290.5000',
#    '2. high': '296.5552',
#    '3. low': '288.6800',
#    '4. close': '294.0400',
#    '5. volume': '998875'},
#   '2019-02-04': {'1. open': '289.7600',
#    '2. high': '289.7600',
#    '3. low': '282.9000',
#    '4. close': '289.0400',
#    '5. volume': '765140'},
#   '2019-02-01': {'1. open': '292.3800',
#    '2. high': '293.3900',
#    '3. low': '288.0100',
#    '4. close': '291.3600',
#    '5. volume': '519463'},
#   '2019-01-31': {'1. open': '288.6600',
#    '2. high': '294.0700',
#    '3. low': '286.0400',
#    '4. close': '291.9200',
#    '5. volume': '491927'},
#   '2019-01-30': {'1. open': '290.2800',
#    '2. high': '290.9900',
#    '3. low': '286.4000',
#    '4. close': '288.6000',
#    '5. volume': '539043'},
#   '2019-01-29': {'1. open': '290.3700',
#    '2. high': '290.4000',
#    '3. low': '286.1300',
#    '4. close': '288.8200',
#    '5. volume': '516935'},
#   '2019-01-28': {'1. open': '291.0000',
#    '2. high': '291.5000',
#    '3. low': '286.3300',
#    '4. close': '290.2800',
#    '5. volume': '554787'},
#   '2019-01-25': {'1. open': '291.1000',
#    '2. high': '293.6600',
#    '3. low': '287.6300',
#    '4. close': '290.7200',
#    '5. volume': '570707'},
#   '2019-01-24': {'1. open': '289.6100',
#    '2. high': '289.7000',
#    '3. low': '286.1200',
#    '4. close': '287.9900',
#    '5. volume': '353647'},
#   '2019-01-23': {'1. open': '289.4100',
#    '2. high': '292.0349',
#    '3. low': '286.1300',
#    '4. close': '288.2000',
#    '5. volume': '630767'},
#   '2019-01-22': {'1. open': '288.1000',
#    '2. high': '294.4400',
#    '3. low': '285.8198',
#    '4. close': '288.8500',
#    '5. volume': '846062'},
#   '2019-01-18': {'1. open': '286.2800',
#    '2. high': '292.2200',
#    '3. low': '286.0850',
#    '4. close': '291.5000',
#    '5. volume': '990463'},
#   '2019-01-17': {'1. open': '280.1900',
#    '2. high': '284.3400',
#    '3. low': '280.0000',
#    '4. close': '283.9000',
#    '5. volume': '679678'},
#   '2019-01-16': {'1. open': '277.7600',
#    '2. high': '282.1800',
#    '3. low': '277.5050',
#    '4. close': '282.0100',
#    '5. volume': '472999'},
#   '2019-01-15': {'1. open': '274.9700',
#    '2. high': '280.5200',
#    '3. low': '273.3120',
#    '4. close': '278.4900',
#    '5. volume': '570855'},
#   '2019-01-14': {'1. open': '282.0600',
#    '2. high': '282.9300',
#    '3. low': '274.8900',
#    '4. close': '274.9000',
#    '5. volume': '928479'},
#   '2019-01-11': {'1. open': '276.8100',
#    '2. high': '284.3800',
#    '3. low': '275.8700',
#    '4. close': '284.1100',
#    '5. volume': '893320'},
#   '2019-01-10': {'1. open': '274.8000',
#    '2. high': '277.7100',
#    '3. low': '269.2900',
#    '4. close': '277.0300',
#    '5. volume': '965600'},
#   '2019-01-09': {'1. open': '275.8200',
#    '2. high': '282.1000',
#    '3. low': '274.9150',
#    '4. close': '281.1900',
#    '5. volume': '707695'},
#   '2019-01-08': {'1. open': '271.9200',
#    '2. high': '276.5000',
#    '3. low': '267.4300',
#    '4. close': '276.0000',
#    '5. volume': '919879'},
#   '2019-01-07': {'1. open': '256.9700',
#    '2. high': '271.1500',
#    '3. low': '256.9700',
#    '4. close': '271.0000',
#    '5. volume': '1247844'},
#   '2019-01-04': {'1. open': '247.0800',
#    '2. high': '258.4800',
#    '3. low': '246.0000',
#    '4. close': '255.0300',
#    '5. volume': '864514'},
#   '2019-01-03': {'1. open': '245.8300',
#    '2. high': '247.0000',
#    '3. low': '240.1300',
#    '4. close': '243.3600',
#    '5. volume': '868602'},
#   '2019-01-02': {'1. open': '239.9600',
#    '2. high': '249.4000',
#    '3. low': '239.3100',
#    '4. close': '247.9700',
#    '5. volume': '1055029'},
#   '2018-12-31': {'1. open': '240.3500',
#    '2. high': '244.8600',
#    '3. low': '239.5648',
#    '4. close': '244.8400',
#    '5. volume': '719791'},
#   '2018-12-28': {'1. open': '243.5000',
#    '2. high': '247.0900',
#    '3. low': '238.1700',
#    '4. close': '239.4500',
#    '5. volume': '636987'},
#   '2018-12-27': {'1. open': '238.7700',
#    '2. high': '242.4950',
#    '3. low': '233.8500',
#    '4. close': '242.2700',
#    '5. volume': '669599'},
#   '2018-12-26': {'1. open': '230.7400',
#    '2. high': '242.4200',
#    '3. low': '229.4885',
#    '4. close': '242.2000',
#    '5. volume': '1014106'},
#   '2018-12-24': {'1. open': '228.6500',
#    '2. high': '234.2900',
#    '3. low': '224.4301',
#    '4. close': '229.0600',
#    '5. volume': '659961'},
#   '2018-12-21': {'1. open': '235.1900',
#    '2. high': '238.1500',
#    '3. low': '229.2600',
#    '4. close': '230.4900',
#    '5. volume': '1695486'},
#   '2018-12-20': {'1. open': '237.8500',
#    '2. high': '241.1000',
#    '3. low': '230.2090',
#    '4. close': '234.0100',
#    '5. volume': '1092394'},
#   '2018-12-19': {'1. open': '243.8600',
#    '2. high': '247.1400',
#    '3. low': '237.7500',
#    '4. close': '239.2300',
#    '5. volume': '1267197'},
#   '2018-12-18': {'1. open': '244.8600',
#    '2. high': '248.9450',
#    '3. low': '237.5500',
#    '4. close': '240.9100',
#    '5. volume': '1029961'},
#   '2018-12-17': {'1. open': '245.5600',
#    '2. high': '248.5104',
#    '3. low': '240.5000',
#    '4. close': '241.9500',
#    '5. volume': '892260'},
#   '2018-12-14': {'1. open': '249.2000',
#    '2. high': '251.6800',
#    '3. low': '246.0400',
#    '4. close': '246.8500',
#    '5. volume': '910282'},
#   '2018-12-13': {'1. open': '255.7300',
#    '2. high': '256.2350',
#    '3. low': '250.5280',
#    '4. close': '251.5200',
#    '5. volume': '817560'},
#   '2018-12-12': {'1. open': '251.4600',
#    '2. high': '257.4900',
#    '3. low': '248.5446',
#    '4. close': '255.1500',
#    '5. volume': '1135098'},
#   '2018-12-11': {'1. open': '255.0000',
#    '2. high': '256.9300',
#    '3. low': '246.5600',
#    '4. close': '247.8600',
#    '5. volume': '1158845'},
#   '2018-12-10': {'1. open': '251.9300',
#    '2. high': '254.1000',
#    '3. low': '242.7400',
#    '4. close': '251.1000',
#    '5. volume': '2690604'},
#   '2018-12-07': {'1. open': '271.4500',
#    '2. high': '276.1100',
#    '3. low': '252.0000',
#    '4. close': '254.4700',
#    '5. volume': '4231014'},
#   '2018-12-06': {'1. open': '285.0000',
#    '2. high': '293.5450',
#    '3. low': '281.7800',
#    '4. close': '292.9200',
#    '5. volume': '1745171'},
#   '2018-12-04': {'1. open': '304.7800',
#    '2. high': '308.4000',
#    '3. low': '289.2100',
#    '4. close': '291.1300',
#    '5. volume': '1653455'},
#   '2018-12-03': {'1. open': '303.8800',
#    '2. high': '311.3000',
#    '3. low': '302.4700',
#    '4. close': '306.4900',
#    '5. volume': '1384333'},
#   '2018-11-30': {'1. open': '300.0500',
#    '2. high': '301.9500',
#    '3. low': '296.4200',
#    '4. close': '297.7900',
#    '5. volume': '971130'},
#   '2018-11-29': {'1. open': '298.0000',
#    '2. high': '302.7100',
#    '3. low': '297.0200',
#    '4. close': '300.3700',
#    '5. volume': '1097219'},
#   '2018-11-28': {'1. open': '299.1900',
#    '2. high': '302.2906',
#    '3. low': '292.5650',
#    '4. close': '295.1400',
#    '5. volume': '1563832'},
#   '2018-11-27': {'1. open': '296.4300',
#    '2. high': '298.6300',
#    '3. low': '293.8800',
#    '4. close': '296.8300',
#    '5. volume': '1546321'},
#   '2018-11-26': {'1. open': '306.9900',
#    '2. high': '309.2200',
#    '3. low': '299.6000',
#    '4. close': '301.1100',
#    '5. volume': '1152749'},
#   '2018-11-23': {'1. open': '302.7700',
#    '2. high': '307.3800',
#    '3. low': '302.3324',
#    '4. close': '303.3200',
#    '5. volume': '334587'},
#   '2018-11-21': {'1. open': '304.1500',
#    '2. high': '305.9848',
#    '3. low': '301.3100',
#    '4. close': '303.7600',
#    '5. volume': '545292'},
#   '2018-11-20': {'1. open': '304.9700',
#    '2. high': '310.2522',
#    '3. low': '301.0100',
#    '4. close': '302.1400',
#    '5. volume': '1135305'},
#   '2018-11-19': {'1. open': '315.3800',
#    '2. high': '322.4899',
#    '3. low': '311.1866',
#    '4. close': '313.2800',
#    '5. volume': '1031312'},
#   '2018-11-16': {'1. open': '311.0100',
#    '2. high': '316.6400',
#    '3. low': '306.0150',
#    '4. close': '313.5600',
#    '5. volume': '838486'},
#   '2018-11-15': {'1. open': '312.1300',
#    '2. high': '312.5200',
#    '3. low': '306.2300',
#    '4. close': '311.8100',
#    '5. volume': '846004'},
#   '2018-11-14': {'1. open': '315.1500',
#    '2. high': '321.7300',
#    '3. low': '309.0000',
#    '4. close': '313.1300',
#    '5. volume': '1182442'},
#   '2018-11-13': {'1. open': '308.8800',
#    '2. high': '314.2900',
#    '3. low': '305.5133',
#    '4. close': '314.2500',
#    '5. volume': '802807'},
#   '2018-11-12': {'1. open': '308.5000',
#    '2. high': '312.3800',
#    '3. low': '305.5000',
#    '4. close': '308.9900',
#    '5. volume': '1152564'},
#   '2018-11-09': {'1. open': '303.7000',
#    '2. high': '312.2000',
#    '3. low': '302.1500',
#    '4. close': '308.1200',
#    '5. volume': '1552067'},
#   '2018-11-08': {'1. open': '281.7600',
#    '2. high': '308.8800',
#    '3. low': '275.1100',
#    '4. close': '304.4900',
#    '5. volume': '1955801'},
#   '2018-11-07': {'1. open': '295.0100',
#    '2. high': '297.7600',
#    '3. low': '287.0000',
#    '4. close': '290.5100',
#    '5. volume': '1622045'},
#   '2018-11-06': {'1. open': '286.2000',
#    '2. high': '292.3748',
#    '3. low': '285.3400',
#    '4. close': '291.7900',
#    '5. volume': '1092971'},
#   '2018-11-05': {'1. open': '283.3400',
#    '2. high': '288.6500',
#    '3. low': '282.5400',
#    '4. close': '285.1300',
#    '5. volume': '1134881'},
#   '2018-11-02': {'1. open': '275.3600',
#    '2. high': '282.2400',
#    '3. low': '275.0400',
#    '4. close': '281.9500',
#    '5. volume': '957365'},
#   '2018-11-01': {'1. open': '275.9000',
#    '2. high': '277.7300',
#    '3. low': '272.2100',
#    '4. close': '272.9500',
#    '5. volume': '703825'},
#   '2018-10-31': {'1. open': '271.4200',
#    '2. high': '277.6500',
#    '3. low': '271.4100',
#    '4. close': '274.5200',
#    '5. volume': '939484'},
#   '2018-10-30': {'1. open': '278.6000',
#    '2. high': '279.5325',
#    '3. low': '263.9400',
#    '4. close': '266.9900',
#    '5. volume': '1455616'},
#   '2018-10-29': {'1. open': '278.4300',
#    '2. high': '285.4300',
#    '3. low': '275.4000',
#    '4. close': '278.5000',
#    '5. volume': '1015701'},
#   '2018-10-26': {'1. open': '268.0200',
#    '2. high': '276.0700',
#    '3. low': '266.0000',
#    '4. close': '274.8900',
#    '5. volume': '839824'},
#   '2018-10-25': {'1. open': '267.7300',
#    '2. high': '273.6050',
#    '3. low': '266.3400',
#    '4. close': '272.2400',
#    '5. volume': '693334'},
#   '2018-10-24': {'1. open': '271.7200',
#    '2. high': '275.2450',
#    '3. low': '266.7800',
#    '4. close': '267.0300',
#    '5. volume': '794681'},
#   '2018-10-23': {'1. open': '270.5000',
#    '2. high': '272.4200',
#    '3. low': '263.0050',
#    '4. close': '272.0500',
#    '5. volume': '958982'},
#   '2018-10-22': {'1. open': '271.9100',
#    '2. high': '275.1500',
#    '3. low': '270.9250',
#    '4. close': '274.6100',
#    '5. volume': '1138266'},
#   '2018-10-19': {'1. open': '275.5000',
#    '2. high': '277.8580',
#    '3. low': '270.6200',
#    '4. close': '270.7800',
#    '5. volume': '977601'},
#   '2018-10-18': {'1. open': '280.6300',
#    '2. high': '283.1700',
#    '3. low': '271.2600',
#    '4. close': '273.4400',
#    '5. volume': '846982'},
#   '2018-10-17': {'1. open': '286.3300',
#    '2. high': '287.0500',
#    '3. low': '278.9600',
#    '4. close': '281.9200',
#    '5. volume': '521647'},
#   '2018-10-16': {'1. open': '283.6600',
#    '2. high': '286.5500',
#    '3. low': '278.2300',
#    '4. close': '285.4100',
#    '5. volume': '731156'},
#   '2018-10-15': {'1. open': '276.1500',
#    '2. high': '285.0100',
#    '3. low': '275.0800',
#    '4. close': '281.7300',
#    '5. volume': '882989'},
#   '2018-10-12': {'1. open': '272.0800',
#    '2. high': '277.9300',
# ...
#   '2016-07-21': {'1. open': '255.1500',
#    '2. high': '256.7800',
#    '3. low': '254.6200',
#    '4. close': '254.9100',
#    '5. volume': '449538'},
#   '2016-07-20': {'1. open': '257.4200',
#    '2. high': '257.5400',
#    '3. low': '255.6800',
#    '4. close': '255.8000',
#    '5. volume': '481763'},
#   '2016-07-19': {'1. open': '256.0000',
#    '2. high': '256.9100',
#    '3. low': '254.5300',
#    '4. close': '256.9100',
#    '5. volume': '383556'},
#   '2016-07-18': {'1. open': '256.0200',
#    '2. high': '256.8400',
#    '3. low': '255.1000',
#    '4. close': '256.0900',
#    '5. volume': '544993'},
#   '2016-07-15': {'1. open': '256.8300',
#    '2. high': '256.8800',
#    '3. low': '255.2550',
#    '4. close': '255.8100',
#    '5. volume': '666549'},
#   '2016-07-14': {'1. open': '251.9500',
#    '2. high': '255.3000',
#    '3. low': '251.3000',
#    '4. close': '255.1100',
#    '5. volume': '786061'},
#   '2016-07-13': {'1. open': '252.9900',
#    '2. high': '253.7650',
#    '3. low': '250.0500',
#    '4. close': '250.1300',
#    '5. volume': '471736'},
#   '2016-07-12': {'1. open': '253.8800',
#    '2. high': '254.6550',
#    '3. low': '251.3000',
#    '4. close': '253.2500',
#    '5. volume': '553940'},
#   '2016-07-11': {'1. open': '252.0000',
#    '2. high': '253.2000',
#    '3. low': '250.6500',
#    '4. close': '252.2900',
#    '5. volume': '504071'},
#   '2016-07-08': {'1. open': '248.5200',
#    '2. high': '253.1100',
#    '3. low': '247.5100',
#    '4. close': '250.8200',
#    '5. volume': '742598'},
#   '2016-07-07': {'1. open': '247.6700',
#    '2. high': '248.6800',
#    '3. low': '245.0600',
#    '4. close': '247.2900',
#    '5. volume': '514576'},
#   '2016-07-06': {'1. open': '244.5700',
#    '2. high': '248.4200',
#    '3. low': '244.3101',
#    '4. close': '247.7700',
#    '5. volume': '758495'},
#   '2016-07-05': {'1. open': '243.4400',
#    '2. high': '245.3000',
#    '3. low': '242.4000',
#    '4. close': '244.7200',
#    '5. volume': '604098'},
#   '2016-07-01': {'1. open': '242.8700',
#    '2. high': '245.3800',
#    '3. low': '241.0200',
#    '4. close': '243.7400',
#    '5. volume': '561207'},
#   '2016-06-30': {'1. open': '242.0000',
#    '2. high': '244.0000',
#    '3. low': '240.1800',
#    '4. close': '243.6400',
#    '5. volume': '615012'},
#   '2016-06-29': {'1. open': '238.5000',
#    '2. high': '241.8250',
#    '3. low': '237.8401',
#    '4. close': '240.6600',
#    '5. volume': '749779'},
#   '2016-06-28': {'1. open': '237.0800',
#    '2. high': '237.5000',
#    '3. low': '234.6200',
#    '4. close': '236.2100',
#    '5. volume': '793855'},
#   '2016-06-27': {'1. open': '236.7800',
#    '2. high': '238.5550',
#    '3. low': '232.5700',
#    '4. close': '235.0400',
#    '5. volume': '826386'},
#   '2016-06-24': {'1. open': '236.1400',
#    '2. high': '242.9100',
#    '3. low': '236.0100',
#    '4. close': '239.1600',
#    '5. volume': '1463572'},
#   '2016-06-23': {'1. open': '240.0500',
#    '2. high': '242.2300',
#    '3. low': '238.3400',
#    '4. close': '242.0800',
#    '5. volume': '601680'},
#   '2016-06-22': {'1. open': '241.0800',
#    '2. high': '241.1199',
#    '3. low': '238.1100',
#    '4. close': '238.2300',
#    '5. volume': '623192'},
#   '2016-06-21': {'1. open': '240.9000',
#    '2. high': '241.4300',
#    '3. low': '239.7000',
#    '4. close': '240.4700',
#    '5. volume': '485120'},
#   '2016-06-20': {'1. open': '240.7500',
#    '2. high': '241.8800',
#    '3. low': '239.1800',
#    '4. close': '240.2000',
#    '5. volume': '647220'},
#   '2016-06-17': {'1. open': '239.7000',
#    '2. high': '239.9800',
#    '3. low': '237.8900',
#    '4. close': '238.0400',
#    '5. volume': '853878'},
#   '2016-06-16': {'1. open': '237.0800',
#    '2. high': '240.4100',
#    '3. low': '236.6300',
#    '4. close': '239.8200',
#    '5. volume': '562632'},
#   '2016-06-15': {'1. open': '237.8900',
#    '2. high': '240.3300',
#    '3. low': '237.6500',
#    '4. close': '238.2300',
#    '5. volume': '577665'},
#   '2016-06-14': {'1. open': '237.9200',
#    '2. high': '239.3190',
#    '3. low': '235.5986',
#    '4. close': '237.8800',
#    '5. volume': '559478'},
#   '2016-06-13': {'1. open': '237.2100',
#    '2. high': '240.8300',
#    '3. low': '237.2100',
#    '4. close': '237.9500',
#    '5. volume': '578477'},
#   '2016-06-10': {'1. open': '237.8200',
#    '2. high': '240.2400',
#    '3. low': '237.8000',
#    '4. close': '239.9800',
#    '5. volume': '526280'},
#   '2016-06-09': {'1. open': '237.7300',
#    '2. high': '240.5100',
#    '3. low': '237.7300',
#    '4. close': '240.0100',
#    '5. volume': '550430'},
#   '2016-06-08': {'1. open': '240.0000',
#    '2. high': '240.6900',
#    '3. low': '238.4600',
#    '4. close': '239.3600',
#    '5. volume': '409223'},
#   '2016-06-07': {'1. open': '236.7900',
#    '2. high': '239.9500',
#    '3. low': '236.5000',
#    '4. close': '239.1800',
#    '5. volume': '716451'},
#   '2016-06-06': {'1. open': '238.6600',
#    '2. high': '238.7500',
#    '3. low': '234.6300',
#    '4. close': '236.7400',
#    '5. volume': '490345'},
#   '2016-06-03': {'1. open': '236.8000',
#    '2. high': '237.3200',
#    '3. low': '234.1800',
#    '4. close': '236.5700',
#    '5. volume': '778378'},
#   '2016-06-02': {'1. open': '236.2400',
#    '2. high': '238.7600',
#    '3. low': '234.8100',
#    '4. close': '237.0600',
#    '5. volume': '781182'},
#   '2016-06-01': {'1. open': '233.2900',
#    '2. high': '236.8550',
#    '3. low': '232.6000',
#    '4. close': '236.6800',
#    '5. volume': '871507'},
#   '2016-05-31': {'1. open': '233.4800',
#    '2. high': '234.1480',
#    '3. low': '231.3600',
#    '4. close': '233.0100',
#    '5. volume': '2141883'},
#   '2016-05-27': {'1. open': '230.7500',
#    '2. high': '237.5300',
#    '3. low': '228.5300',
#    '4. close': '233.1500',
#    '5. volume': '3584534'},
#   '2016-05-26': {'1. open': '214.0000',
#    '2. high': '214.4400',
#    '3. low': '211.5501',
#    '4. close': '213.6900',
#    '5. volume': '1885862'},
#   '2016-05-25': {'1. open': '206.6100',
#    '2. high': '212.2600',
#    '3. low': '206.6100',
#    '4. close': '211.4800',
#    '5. volume': '1238574'},
#   '2016-05-24': {'1. open': '208.4800',
#    '2. high': '209.7200',
#    '3. low': '206.4200',
#    '4. close': '206.5900',
#    '5. volume': '1391397'},
#   '2016-05-23': {'1. open': '208.9700',
#    '2. high': '209.9800',
#    '3. low': '205.9500',
#    '4. close': '206.0200',
#    '5. volume': '964258'},
#   '2016-05-20': {'1. open': '208.7300',
#    '2. high': '208.9500',
#    '3. low': '206.0600',
#    '4. close': '208.4700',
#    '5. volume': '968999'},
#   '2016-05-19': {'1. open': '205.0000',
#    '2. high': '208.6300',
#    '3. low': '205.0000',
#    '4. close': '207.8900',
#    '5. volume': '523352'},
#   '2016-05-18': {'1. open': '204.4500',
#    '2. high': '208.3050',
#    '3. low': '203.1800',
#    '4. close': '206.4500',
#    '5. volume': '1032977'},
#   '2016-05-17': {'1. open': '207.2100',
#    '2. high': '208.2400',
#    '3. low': '203.2800',
#    '4. close': '204.4400',
#    '5. volume': '875452'},
#   '2016-05-16': {'1. open': '204.8500',
#    '2. high': '209.0900',
#    '3. low': '204.3900',
#    '4. close': '208.1300',
#    '5. volume': '482645'},
#   '2016-05-13': {'1. open': '207.0300',
#    '2. high': '207.5400',
#    '3. low': '203.2900',
#    '4. close': '205.2000',
#    '5. volume': '633440'},
#   '2016-05-12': {'1. open': '203.7000',
#    '2. high': '208.4096',
#    '3. low': '203.0000',
#    '4. close': '207.4300',
#    '5. volume': '761781'},
#   '2016-05-11': {'1. open': '207.0100',
#    '2. high': '207.7000',
#    '3. low': '202.2800',
#    '4. close': '202.8500',
#    '5. volume': '951983'},
#   '2016-05-10': {'1. open': '209.2500',
#    '2. high': '209.2500',
#    '3. low': '205.7900',
#    '4. close': '208.2700',
#    '5. volume': '854348'},
#   '2016-05-09': {'1. open': '205.6500',
#    '2. high': '210.2500',
#    '3. low': '204.5990',
#    '4. close': '208.4600',
#    '5. volume': '800551'},
#   '2016-05-06': {'1. open': '205.2000',
#    '2. high': '208.9300',
#    '3. low': '204.0500',
#    '4. close': '208.6800',
#    '5. volume': '774132'},
#   '2016-05-05': {'1. open': '209.7800',
#    '2. high': '209.7800',
#    '3. low': '204.4600',
#    '4. close': '206.2100',
#    '5. volume': '844002'},
#   '2016-05-04': {'1. open': '209.0500',
#    '2. high': '211.0100',
#    '3. low': '208.7050',
#    '4. close': '209.9700',
#    '5. volume': '543602'},
#   '2016-05-03': {'1. open': '208.4000',
#    '2. high': '210.3350',
#    '3. low': '206.7400',
#    '4. close': '209.9100',
#    '5. volume': '901037'},
#   '2016-05-02': {'1. open': '208.2900',
#    '2. high': '210.7700',
#    '3. low': '207.5400',
#    '4. close': '210.7200',
#    '5. volume': '667043'},
#   '2016-04-29': {'1. open': '206.4600',
#    '2. high': '208.5400',
#    '3. low': '205.2500',
#    '4. close': '208.2800',
#    '5. volume': '826387'},
#   '2016-04-28': {'1. open': '211.5100',
#    '2. high': '211.9700',
#    '3. low': '206.5800',
#    '4. close': '206.9900',
#    '5. volume': '891509'},
#   '2016-04-27': {'1. open': '207.3200',
#    '2. high': '212.9200',
#    '3. low': '207.3200',
#    '4. close': '212.5200',
#    '5. volume': '1388255'},
#   '2016-04-26': {'1. open': '207.0400',
#    '2. high': '208.2200',
#    '3. low': '205.3600',
#    '4. close': '208.1300',
#    '5. volume': '1126817'},
#   '2016-04-25': {'1. open': '205.0800',
#    '2. high': '207.8300',
#    '3. low': '203.9500',
#    '4. close': '207.3700',
#    '5. volume': '959953'},
#   '2016-04-22': {'1. open': '205.4200',
#    '2. high': '206.4800',
#    '3. low': '202.6850',
#    '4. close': '205.3900',
#    '5. volume': '995261'},
#   '2016-04-21': {'1. open': '204.6200',
#    '2. high': '207.6700',
#    '3. low': '204.3900',
#    '4. close': '205.8600',
#    '5. volume': '855314'},
#   '2016-04-20': {'1. open': '203.9800',
#    '2. high': '205.1200',
#    '3. low': '202.9100',
#    '4. close': '204.4200',
#    '5. volume': '883403'},
#   '2016-04-19': {'1. open': '206.2000',
#    '2. high': '206.5700',
#    '3. low': '203.0900',
#    '4. close': '204.0400',
#    '5. volume': '1162031'},
#   '2016-04-18': {'1. open': '203.9300',
#    '2. high': '207.0500',
#    '3. low': '203.2400',
#    '4. close': '206.9100',
#    '5. volume': '1112765'},
#   '2016-04-15': {'1. open': '206.3400',
#    '2. high': '206.3400',
#    '3. low': '202.3100',
#    '4. close': '204.0600',
#    '5. volume': '11411000'},
#   '2016-04-14': {'1. open': '207.7200',
#    '2. high': '207.7200',
#    '3. low': '204.6600',
#    '4. close': '205.6700',
#    '5. volume': '1365074'},
#   '2016-04-13': {'1. open': '205.4400',
#    '2. high': '207.7500',
#    '3. low': '205.0250',
#    '4. close': '207.4200',
#    '5. volume': '1116392'},
#   '2016-04-12': {'1. open': '203.5000',
#    '2. high': '205.1100',
#    '3. low': '201.6375',
#    '4. close': '203.9400',
#    '5. volume': '1190993'},
#   '2016-04-11': {'1. open': '201.5100',
#    '2. high': '204.6200',
#    '3. low': '200.6300',
#    '4. close': '202.1000',
#    '5. volume': '1598833'},
#   '2016-04-08': {'1. open': '201.9400',
#    '2. high': '203.7500',
#    '3. low': '197.8100',
#    '4. close': '200.5100',
#    '5. volume': '3611916'},
#   '2016-04-07': {'1. open': '194.1200',
#    '2. high': '195.0400',
#    '3. low': '191.8500',
#    '4. close': '194.1200',
#    '5. volume': '866982'},
#   '2016-04-06': {'1. open': '193.9100',
#    '2. high': '196.6000',
#    '3. low': '193.4200',
#    '4. close': '194.6700',
#    '5. volume': '657665'},
#   '2016-04-05': {'1. open': '192.2700',
#    '2. high': '195.0200',
#    '3. low': '192.0100',
#    '4. close': '193.7500',
#    '5. volume': '765272'},
#   '2016-04-04': {'1. open': '194.6800',
#    '2. high': '194.8400',
#    '3. low': '191.3700',
#    '4. close': '193.1200',
#    '5. volume': '583739'},
#   '2016-04-01': {'1. open': '192.6200',
#    '2. high': '195.6056',
#    '3. low': '192.0979',
#    '4. close': '194.1800',
#    '5. volume': '507177'},
#   '2016-03-31': {'1. open': '193.8700',
#    '2. high': '194.9399',
#    '3. low': '192.6200',
#    '4. close': '193.7400',
#    '5. volume': '737320'},
#   '2016-03-30': {'1. open': '194.8700',
#    '2. high': '195.0000',
#    '3. low': '192.3300',
#    '4. close': '194.1100',
#    '5. volume': '613695'},
#   '2016-03-29': {'1. open': '192.5500',
#    '2. high': '193.9300',
#    '3. low': '191.5300',
#    '4. close': '193.3700',
#    '5. volume': '541910'},
#   '2016-03-28': {'1. open': '191.8400',
#    '2. high': '193.6000',
#    '3. low': '190.7400',
#    '4. close': '191.9100',
#    '5. volume': '475792'},
#   '2016-03-24': {'1. open': '191.4000',
#    '2. high': '192.7083',
#    '3. low': '190.6168',
#    '4. close': '191.7600',
#    '5. volume': '621177'},
#   '2016-03-23': {'1. open': '191.2200',
#    '2. high': '193.0700',
#    '3. low': '190.7700',
#    '4. close': '191.5700',
#    '5. volume': '527300'},
#   '2016-03-22': {'1. open': '190.4400',
#    '2. high': '192.5000',
#    '3. low': '189.4600',
#    '4. close': '191.6500',
#    '5. volume': '881850'},
#   '2016-03-21': {'1. open': '190.8800',
#    '2. high': '193.7800',
#    '3. low': '190.2100',
#    '4. close': '192.3500',
#    '5. volume': '1037799'},
#   '2016-03-18': {'1. open': '188.3200',
#    '2. high': '192.3800',
#    '3. low': '187.9000',
#    '4. close': '191.3900',
#    '5. volume': '1096111'},
#   '2016-03-17': {'1. open': '189.4400',
#    '2. high': '190.6800',
#    '3. low': '187.4600',
#    '4. close': '188.0100',
#    '5. volume': '1029297'},
#   '2016-03-16': {'1. open': '187.1000',
#    '2. high': '191.0000',
#    '3. low': '186.6000',
#    '4. close': '190.0200',
#    '5. volume': '936721'},
#   '2016-03-15': {'1. open': '189.0200',
#    '2. high': '191.0100',
#    '3. low': '187.6500',
#    '4. close': '187.8700',
#    '5. volume': '1185158'},
#   '2016-03-14': {'1. open': '189.5200',
#    '2. high': '191.9100',
#    '3. low': '188.8400',
#    '4. close': '190.0200',
#    '5. volume': '1700095'},
#   '2016-03-11': {'1. open': '186.6000',
#    '2. high': '192.0600',
#    '3. low': '184.1000',
#    '4. close': '191.6200',
#    '5. volume': '6130719'},
#   '2016-03-10': {'1. open': '159.5600',
#    '2. high': '164.3200',
#    '3. low': '158.5000',
#    '4. close': '163.3900',
#    '5. volume': '3753301'},
#   '2016-03-09': {'1. open': '164.7000',
#    '2. high': '165.9700',
#    '3. low': '158.2100',
#    '4. close': '159.0100',
#    '5. volume': '2445401'},
#   '2016-03-08': {'1. open': '164.3400',
#    '2. high': '165.4800',
#    '3. low': '162.4700',
#    '4. close': '162.9600',
#    '5. volume': '1571546'},
#   '2016-03-07': {'1. open': '168.5700',
#    '2. high': '168.8900',
#    '3. low': '163.0500',
#    '4. close': '164.6400',
#    '5. volume': '1238029'},
#   '2016-03-04': {'1. open': '169.9600',
#    '2. high': '170.0500',
#    '3. low': '167.5800',
#    '4. close': '168.9700',
#    '5. volume': '628748'},
#   '2016-03-03': {'1. open': '167.4100',
#    '2. high': '171.1906',
#    '3. low': '166.0000',
#    '4. close': '169.3800',
#    '5. volume': '1124432'},
#   '2016-03-02': {'1. open': '168.2100',
#    '2. high': '168.8600',
#    '3. low': '165.7100',
#    '4. close': '168.3200',
#    '5. volume': '776315'},
#   '2016-03-01': {'1. open': '165.8600',
#    '2. high': '168.6500',
#    '3. low': '164.2000',
#    '4. close': '168.4100',
#    '5. volume': '1053590'},
#   '2016-02-29': {'1. open': '165.0000',
#    '2. high': '168.5000',
#    '3. low': '164.0000',
#    '4. close': '165.1900',
#    '5. volume': '1183070'},
#   '2016-02-26': {'1. open': '165.5700',
#    '2. high': '166.9700',
#    '3. low': '162.5400',
#    '4. close': '164.7500',
#    '5. volume': '1205134'},
#   '2016-02-25': {'1. open': '161.5200',
#    '2. high': '164.2700',
#    '3. low': '160.8750',
#    '4. close': '164.2500',
#    '5. volume': '1408134'},
#   '2016-02-24': {'1. open': '156.5200',
#    '2. high': '161.2300',
#    '3. low': '156.0000',
#    '4. close': '160.7500',
#    '5. volume': '1247979'},
#   '2016-02-23': {'1. open': '156.6300',
#    '2. high': '161.4600',
#    '3. low': '156.3000',
#    '4. close': '159.1700',
#    '5. volume': '1924192'},
#   '2016-02-22': {'1. open': '151.0000',
#    '2. high': '156.8700',
#    '3. low': '150.4300',
#    '4. close': '156.2700',
#    '5. volume': '1571990'},
#   '2016-02-19': {'1. open': '153.1600',
#    '2. high': '153.3850',
#    '3. low': '146.7700',
#    '4. close': '150.0700',
#    '5. volume': '2825554'},
#   '2016-02-18': {'1. open': '155.3300',
#    '2. high': '155.9500',
#    '3. low': '147.2500',
#    '4. close': '154.5500',
#    '5. volume': '3673523'},
#   '2016-02-17': {'1. open': '160.5100',
#    '2. high': '162.8900',
#    '3. low': '158.1600',
#    '4. close': '158.9200',
#    '5. volume': '1443793'},
#   '2016-02-16': {'1. open': '160.6100',
#    '2. high': '161.8900',
#    '3. low': '157.6000',
#    '4. close': '159.0200',
#    '5. volume': '971400'},
#   ...}}

# %%
response['Meta Data']
# Out:
# {'1. Information': 'Daily Prices (open, high, low, close) and Volumes',
#  '2. Symbol': 'ULTA',
#  '3. Last Refreshed': '2020-02-04',
#  '4. Output Size': 'Full size',
#  '5. Time Zone': 'US/Eastern'}

# %%
time_series= response['Time Series (Daily)']
timestamp = list(time_series.keys())
values= list(time_series.values())

# %%
df = pd.DataFrame.from_dict(values)
df["timestamp"] = timestamp
df = df.set_index('timestamp')

# %%
df.head()
# Out:
#              1. open   2. high    3. low  4. close 5. volume
# timestamp
# 2020-02-04  277.5200  279.8800  272.8600  273.5200    957657
# 2020-02-03  273.0000  280.0000  272.1600  274.9600    947958
# 2020-01-31  274.2700  274.2700  266.7375  267.9100    730840
# 2020-01-30  270.5500  275.0000  270.1500  274.4900    621514
# 2020-01-29  274.5000  275.6900  271.1100  273.9800    476980

# %%
export_csv = df.to_csv("ULTA.CSV", index=True, header=True)
